# %%
# !git clone https://github.com/KharchenkoAnastasia/Winstars_internship_test.git
# Out:
# Cloning into 'Winstars_internship_test'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 53 (delta 10), reused 18 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 4.54 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
! python /content/Winstars_internship_test/task2/vision/inference.py \
  --image_path /content/Winstars_internship_test/task2/data/cat.jpg \
  --model_path /content/Winstars_internship_test/task2/vision/model/model.h5 \
  --labels_path /content/Winstars_internship_test/task2/vision/model/label_classes.npy \
  --target_size 224
# Out:
# 2026-03-19 22:55:43.975218: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 22:55:43.981019: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 22:55:43.996560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773960944.022344    5268 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773960944.029190    5268 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773960944.047634    5268 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773960944.047735    5268 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773960944.047740    5268 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773960944.047745    5268 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-19 22:55:44.053286: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] Loading model...
# 2026-03-19 22:55:51.780680: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [INFO] Loading labels...
# [INFO] Preprocessing image...
# [INFO] Running prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# Predicted label: tiger, Confidence: 0.1869

# %%
# !python /content/Winstars_internship_test/task2/ner/inference.py \
  --test_sentence "The rabbit hopped across the garden" \
  --model_path /content/Winstars_internship_test/task2/ner/ner_model
# Out:
# Loading weights: 100% 199/199 [00:00<00:00, 953.43it/s, Materializing param=classifier.weight]
# {'sentence': 'The rabbit hopped across the garden', 'tokens': ['The', 'rabbit', 'hopped', 'across', 'the', 'garden'], 'labels': ['O', 'B-ANIMAL', 'O', 'O', 'O', 'B-ANIMAL'], 'animals': ['rabbit', 'garden']}

# %%
# !python /content/Winstars_internship_test/task2/pipeline.py \
  --text_input "Wow! That dog is so cute!!" \
  --image_path /content/Winstars_internship_test/task2/data/dog.jpg \
  --ner_model_path /content/Winstars_internship_test/task2/ner/ner_model \
  --cv_model_path /content/Winstars_internship_test/task2/vision/model/model.h5 \
  --labels_path /content/Winstars_internship_test/task2/vision/model/label_classes.npy
# Out:
# 2026-03-19 22:59:06.766425: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 22:59:06.778487: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 22:59:06.807216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773961146.848600    6066 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773961146.861243    6066 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773961146.902570    6066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961146.902639    6066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961146.902648    6066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961146.902656    6066 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-19 22:59:06.915261: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights: 100% 199/199 [00:00<00:00, 1186.33it/s, Materializing param=classifier.weight]
# [INFO] Loading model...
# 2026-03-19 22:59:15.944393: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# [INFO] Loading labels...
# [INFO] Preprocessing image...
# [INFO] Running prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Text animal: dog
# Image prediction: tiger (0.2461)
# The predictions from both models are different.
# False
