# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
tf.get_logger().setLevel('ERROR')

# %%
# !git clone https://github.com/KharchenkoAnastasia/Winstars_internship_test.git
# Out:
# Cloning into 'Winstars_internship_test'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 53 (delta 10), reused 18 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 4.54 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
! python /content/Winstars_internship_test/task2/vision/inference.py \
  --image_path /content/Winstars_internship_test/task2/data/cat.jpg \
  --model_path /content/Winstars_internship_test/task2/vision/model/model.h5 \
  --labels_path /content/Winstars_internship_test/task2/vision/model/label_classes.npy \
  --target_size 224
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773961587.010233    7933 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773961587.021870    7933 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773961587.050355    7933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961587.050440    7933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961587.050450    7933 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/Winstars_internship_test/task2/ner/inference.py \
  --test_sentence "The rabbit hopped across the garden" \
  --model_path /content/Winstars_internship_test/task2/ner/ner_model
# Out:
# Loading weights: 100% 199/199 [00:00<00:00, 1238.36it/s, Materializing param=classifier.weight]
# {'sentence': 'The rabbit hopped across the garden', 'tokens': ['The', 'rabbit', 'hopped', 'across', 'the', 'garden'], 'labels': ['O', 'B-ANIMAL', 'O', 'O', 'O', 'B-ANIMAL'], 'animals': ['rabbit', 'garden']}

# %%
# !python /content/Winstars_internship_test/task2/pipeline.py \
  --text_input "Wow! That dog is so cute!!" \
  --image_path /content/Winstars_internship_test/task2/data/dog.jpg \
  --ner_model_path /content/Winstars_internship_test/task2/ner/ner_model \
  --cv_model_path /content/Winstars_internship_test/task2/vision/model/model.h5 \
  --labels_path /content/Winstars_internship_test/task2/vision/model/label_classes.npy
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773961624.653547    8086 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773961624.666084    8086 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773961624.695067    8086 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961624.695146    8086 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773961624.695156    8086 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
